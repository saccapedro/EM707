# %% [markdown]
# # Tentativa

# %%
import control as ct
import matplotlib.pyplot as plt

sys = ct.tf([1],[1, 0.5, 1])

cplt = ct.step_response(sys).plot()
ct.step_info(sys)
# Out:
# {'RiseTime': 1.2559555052694797,
#  'SettlingTime': 14.317892760072068,
#  'SettlingMin': 0.8027288481943778,
#  'SettlingMax': 1.444247875271533,
#  'Overshoot': 44.424787527153306,
#  'Undershoot': 0.0,
#  'Peak': 1.444247875271533,
#  'PeakTime': 3.265484313700647,
#  'SteadyStateValue': 1.0}
